# %% [markdown]
# #### Using Jupyter notebooks
# - List
# - $\TeX$
# $$\sum_{i=1}^{N}i^{2}=\frac{N(N+1)(2N+1)}{6}$$
# - Code block
# ```python
# print "Hello World"
# ```
# - Tables
# Column 1 | Column 2
# ---------|----------
# Row 1 | Entry 1
# Row 1 | Entry 2

# %%
print "Hello"
# Out:
# Hello

# %%
def factorial(x):
    if x <= 1:
        return 1
    else:
        return x * factorial(x-1)

# %%
factorial(5)
# Out:
# 120

# %%
num_points = 50
xdata = np.zeros((num_points, 1))
ydata = np.zeros((num_points, 1))

# For loop
for i in range(1, num_points):
    xdata[i] = i
    ydata[i] = factorial(i)

# %%
import mumpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-aa31ee31864d> in <module>()
# ----> 1 import mumpy as np
#
# ImportError: No module named mumpy

# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

from palettable.colorbrewer.sequential import Oranges_9

# %%
plt.plot(xdata, ydata)

# %%
fig = plt.figure(figsize=(4,3), dpi=200)

myriadpro = fm.FontProperties(fname='/usr/share/fonts/truetype/MyriadPro-Regular.ttf')

plt.semilogy(xdata, ydata, color=Oranges_9.mpl_colors[3], alpha=0.4, zorder=1)
plt.scatter(xdata, ydata, color=Oranges_9.mpl_colors[5], s=4, alpha=1.0, zorder=2)

plt.title('Title', fontproperties=myriadpro)
plt.xlabel('X Axis', fontproperties=myriadpro)
plt.ylabel('Y Axis', fontproperties=myriadpro)

plt.tick_params(direction='out', length=5, width=1.5)
plt.tight_layout()
plt.savefig('Plot.png')
